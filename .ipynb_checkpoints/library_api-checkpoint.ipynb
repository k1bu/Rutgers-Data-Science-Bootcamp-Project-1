# %%
# Getting a list of Seattle Public Libraries
# We want to demostrate the use of APIs

# Dependencies (don't need all of the)
import requests
import json
import os
import gmaps
from pandas.io.json import json_normalize
import numpy as np
import pandas as pd
import requests
import time
import requests
from pandas import DataFrame
from pandas.io.json import json_normalize 

# Google  API key
from config import gkey

gmaps.configure(api_key=gkey)

# %%
target_coordinates = "47.6038,-122.3301"
target_search = "The Seattle Public Library"
target_radius = 50000
target_type = "public library"

# Setting up parameters
params = {
    "location": target_coordinates,
    "keyword": target_search,
    "radius": target_radius,
    "type": target_type,
    "key": gkey
}

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
response = requests.get(base_url, params=params)

# %%
print(response)
# Out:
# <Response [200]>

# %%
# convert response to json
library_data = response.json()

# Print the json (pretty printed)
print(json.dumps(library_data, indent=4, sort_keys=True))
# Out:
# {
#     "html_attributions": [],
#     "next_page_token": "CtQCQQEAAIlQbs84Rz6817nE2pnDa742qydOBFeIF3i4BhcsuDE_19xeFR8uvMfDmRnK5x4siwVOo7vwuSxCMDOWk_6SRu59kyTEtGAu4HQ6_2hHGOjt_xgbF7wSCP11e8fvhBIMWrW5wtEMMifnP6miXh0Vk94vS4esIl5DYsjINEQYeWT5xbO9w6PkUIMVX10mqJjIEGJGmB6wYvjUra524iGWWP_ZZMbc4Q-GEHL7_cRdzLNzgNQ23a_bzyB9B7bp23LpXEqKqgoitB2-HSYfHKsgD2230-nywu7bRQ4nT3Q3HtjE6Ou-o2JJMY2kzeKi7MTS7Rvx8aocoL22nYMtSXENN0rJpBw6t7n7U21H-lAM9O9csQfNFBI6rHXZjqSokxOLryAm7j6qmhLHZnekpqIF2w0w6uuDJvcCnWDPAkJt0y2E85fn-WBW5NCzi2Xiv40RPhIQdEXbBzTzSHxQDvFX1erGMBoUnLuOlxIX3vuytzhn0Dc-DvmMWLM",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 47.6067006,
#                     "lng": -122.3325009
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 47.60810397989272,
#                         "lng": -122.3313352201073
#                     },
# ...

# %%
# Print the name and address of the first restaurant that appears

print(library_data["results"][1]["name"])
print(library_data["results"][1]["vicinity"])
print(library_data["results"][1]["geometry"]["location"])
# Out:
# Broadview Branch - The Seattle Public Library
# 12755 Greenwood Ave N, Seattle
# {'lat': 47.7229573, 'lng': -122.356098}

# %%
print(len(library_data["results"]))
# Out:
# 20

# %%
# printing locations for all 20 Seattle libraries.
# map in presentation is snip it from The Seattle Public Library site


i = 0 
while i < 20: 
    print(library_data["results"][i]["name"])
    print(library_data["results"][i]["vicinity"])
    print(library_data["results"][i]["geometry"]["location"])
    
    #print(library_data["results"][i]["geometry"]["location"]["lat"])
    #print(library_data["results"][i]["geometry"]["location"]["lng"])

    print("                                                                        ")
    print(".............................................................................")
    print("                                                                        ")
    i += 1
# Out:
# Seattle Public Library-Central Library
# 1000 4th Ave, Seattle
# {'lat': 47.6067006, 'lng': -122.3325009}
#
# .............................................................................
#
# Broadview Branch - The Seattle Public Library
# 12755 Greenwood Ave N, Seattle
# {'lat': 47.7229573, 'lng': -122.356098}
#
# .............................................................................
#
# Capitol Hill Branch - The Seattle Public Library
# 425 Harvard Ave E, Seattle
# {'lat': 47.6229294, 'lng': -122.3223185}
#
# .............................................................................
#
# Beacon Hill Branch - The Seattle Public Library
# 5813, 2821 Beacon Ave S, Seattle
# {'lat': 47.5779931, 'lng': -122.3114427}
#
# .............................................................................
#
# Northgate Branch - The Seattle Public Library
# 10548 5th Ave NE, Seattle
# {'lat': 47.7059519, 'lng': -122.3230063}
#
# ...
